# %%
import pandas as pd
import seaborn as sns

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/rounding_rank.csv')

# %%
import matplotlib.pyplot as plt

# %%
kek = kek.rename(columns={'Shreks' : 'Потоки'})

# %%
kek
# Out:
#      Unnamed: 0  initial_rank  rounding_rank  mode_size  kernels      time  \
# 0             0            25             30         10       10  0.537876
# 1             1            25             30         10       10  0.328915
# 2             2            25             30         10       10  0.595760
# 3             3            25             30         10       10  0.366332
# 4             4            25             30         10       10  0.699059
# ..          ...           ...            ...        ...      ...       ...
# 229         229            25            150         10       10  3.885351
# 230         230            25            150         10       10  6.327799
# 231         231            25            150         10       10  3.882814
# 232         232            25            150         10       10  6.368052
# 233         233            25            150         10       10  3.921272
#
#      Потоки  kappa  retry
# 0         1      1      6
# ...

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/rounding_rank.csv')
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'rounding_rank', y = 'time', ax = ax, hue="Потоки")
ax.set_xlabel('Ранг округления')
ax.set_ylabel('Время работы')
# Out:
# Text(0, 0.5, 'Время работы')

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/kernels.csv')
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'kernels', y = 'time', ax = ax, hue="Потоки")
ax.set_xlabel('Количество ядер')
ax.set_ylabel('Время работы')
# Out:
# Text(0, 0.5, 'Время работы')

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/modes.csv')
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'mode_size', y = 'time', ax = ax, hue="Потоки")
ax.set_xlabel('Размер моды тензора')
ax.set_ylabel('Время работы')
# Out:
# Text(0, 0.5, 'Время работы')

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/kappa.csv')
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'kappa', y = 'time', ax = ax, hue="Потоки")
ax.set_xlabel('Каппа')
ax.set_ylabel('Время работы')
# Out:
# Text(0, 0.5, 'Время работы')

# %%
kek = pd.read_csv('/home/divanik/Desktop/CourseWork/Nystrom_TT_rounding_and_convolution/data/experiment2/initial_rank.csv')
sns.set(font_scale=2)
kek['normalized_time'] = kek['time'] / (kek['initial_rank'] ** 4)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'initial_rank', y = 'normalized_time', ax = ax, hue="Потоки")
ax.set_xlabel('Исходный ранг')
ax.set_ylabel('Время работы / (исходный ранг)^4')
# Out:
# Text(0, 0.5, 'Время работы / (исходный ранг)^4')
