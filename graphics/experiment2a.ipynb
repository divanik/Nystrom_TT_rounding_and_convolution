# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
repo_path = '/home/divanik/CourseWork/Nystrom_TT_rounding_and_convolution'

# %%
kek = pd.read_csv(f'{repo_path}/data/experiment3/kappa_dependence.csv')
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=kek, x = 'rounding_rank', y = 'precision', ax = ax, hue="kappa")
ax.set_yscale('log')
ax.set_xlabel('Ранг округления')
ax.set_ylabel('Точность приближения')
# Out:
# Text(0, 0.5, 'Точность приближения')

# %%
input_file = open("luls.txt", "r")

df = []

rank = None
over = None
precision = None

for line in input_file.readlines():
    if line.startswith('Rounding_rank:'):
        rank = int(line.split()[1])
    elif line.startswith('Oversampling:'):
        over = int(line.split()[1])
    elif line.startswith('Retry:'):
        pass
    else:
        precision = float(line[:-1])
        df.append({'precision' : precision, 'rounding_rank' : rank, 'oversampling' : over})

# %%
pd.DataFrame(df).to_csv(f'{repo_path}/data/experiment3/oversampling_dependence.csv')

# %%
pd.set_option('display.max_rows', None)

# %%
import  numpy as np

# %%
kek = pd.read_csv(f'{repo_path}/data/experiment3/oversampling_dependence.csv')
kek = kek[['precision', 'rounding_rank', 'oversampling']]
lol = kek[np.isin(kek['oversampling'], [0, 1, 2, 3, 5, 7])]
display(lol)
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=lol, x = 'rounding_rank', y = 'precision', ax = ax, hue="oversampling")
ax.set_yscale('log')
ax.set_xlabel('Ранг округления')
ax.set_ylabel('Точность приближения')
# Out:
#         precision  rounding_rank  oversampling
# 0    3.213860e-07             35             0
# 1    1.662337e-07             35             1
# 2    1.299047e-07             35             2
# 3    5.972249e-08             35             3
# 4    7.198832e-08             35             5
# 5    4.893040e-08             35             7
# 7    1.146765e-07             35             0
# 8    9.848126e-08             35             1
# 9    1.006336e-07             35             2
# 10   2.518448e-07             35             3
# 11   3.476624e-08             35             5
# 12   8.202653e-09             35             7
# 14   8.594719e-08             35             0
# 15   7.149898e-08             35             1
# 16   8.576763e-08             35             2
# 17   2.981109e-08             35             3
# 18   5.740670e-08             35             5
# 19   2.449961e-08             35             7
# 21   1.695751e-07             35             0
# ...

# %%
kek = pd.read_csv(f'{repo_path}/data/experiment2/RTO_oversampling_dependence.csv')
kek = kek[['precision', 'rounding_rank', 'oversampling']]
lol = kek[np.isin(kek['oversampling'], [0, 1, 2, 3, 5, 7])]
display(lol)
sns.set(font_scale=2)
fig, ax = plt.subplots()
fig.set_size_inches((18, 14))
sns.lineplot(data=lol, x = 'rounding_rank', y = 'precision', ax = ax, hue="oversampling")
ax.set_yscale('log')
ax.set_xlabel('Ранг округления')
ax.set_ylabel('Точность приближения')
# Out:
#         precision  rounding_rank  oversampling
# 0    2.523351e-10             40             0
# 1    1.965770e-10             40             1
# 2    6.171813e-11             40             2
# 3    4.500933e-11             40             3
# 4    2.252886e-11             40             5
# ..            ...            ...           ...
# 265  4.270845e-14             80             1
# 266  2.399697e-14             80             2
# 267  6.349469e-14             80             3
# 268  4.705380e-14             80             5
# 269  2.372009e-14             80             7
#
# [270 rows x 3 columns]
# Text(0, 0.5, 'Точность приближения')
